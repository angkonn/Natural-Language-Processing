# %%
import re
string = "Tiger is the national animal of India. Tiger is a wild animal."
pattern = "Tiger"
result = re.match(pattern,string).group(0)
result
# Out:
# 'Tiger'

# %%
import re
string = "The Tiger is the national animal of India. Tiger is a wild animal."
pattern = "Tiger"
result = re.match(pattern,string).group(0)
result
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       2 string = "The Tiger is the national animal of India. Tiger is a wild animal."
#       3 pattern = "Tiger"
# ----> 4 result = re.match(pattern,string).group(0)
#       5 result
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
import re
string = "The Tiger is the national animal of India. Tiger is a wild animal."
pattern = "Tiger"
result = re.search(pattern,string).group(0)
result
# Out:
# 'Tiger'

# %%
from PIL import Image
from IPython.display import display

image = Image.open('group(0).png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=704x179>

# %%
import re
string = "The Tiger is a national animal and hockey is the national sport"
pattern = "national"
result = re.findall(pattern,string)
result
# Out:
# ['national', 'national']

# %%
matches = re.finditer(pattern, string)
for match in matches:
    print(f"Match: {match.group(0)}, Start: {match.start()}, End: {match.end()}")
# Out:
# Match: national, Start: 15, End: 23
# Match: national, Start: 49, End: 57

# %%
string = "john 32-3456 12-05-2007, XYZ 56-4532 11-11-2011, ABC 67-8945 12-01-2009"
pattern = r'\d{2}-\d{2}-\d{4}'
re.findall(pattern, string)
# Out:
# ['12-05-2007', '11-11-2011', '12-01-2009']

# %%
string = 'this is,a,sample,text,string'
pattern = r'[;,\s]'
re.split(pattern, string)
# Out:
# ['this', 'is', 'a', 'sample', 'text', 'string']

# %%
string = "cricket is the most popular sport of Bangladesh"
pattern = "cricket"
replacement = "football"
re.sub(pattern,replacement,string)
# Out:
# 'football is the most popular sport of Bangladesh'
